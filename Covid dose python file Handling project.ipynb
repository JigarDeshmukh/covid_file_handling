# %%
print("Welcome to covid  1st dose program \n\n")

count=0
while(True):
    print("Select Operation -: \n")
    print("1: Enter user details into database")
    print("2: Read the data from the database")
    print("3: count of doses")
    print("4: Exit\n")
    

    n = input("Enter your Choice -: ")
       
    if(n=='1'):
        count+=1
        print()
        first_name = input("Enter First Name -: ")
        last_name = input("Enter Last Name -: ")
        location = input("Enter Location -: ")
        date=input("Enter the Date-:")
        age = int(input("Enter Age -: "))
        number = int(input("Enter Phone Number -:+91"))
        
        

        details = f"""First Name -: {first_name.title()}
LastName -: {last_name.title()}
Location -: {location.title()}
Age -: {age}
Date-:{date}
Phone Number -: {number}
\n\n\n"""

        with open("covid_vaccine_data.txt","a") as file:
            content = file.write(details)
        print()
        continue
    
    
    elif(n=='2'):
        with open("covid_vaccine_data.txt","r") as file:
            content = file.read()
            print(content)
        print()
    
    
    elif(n=="3"):
         print("count of person in total-:", count)
    
    
    else:
        break
# Out:
# Welcome to covid  1st dose program
#
#
# Select Operation -:
#
# 1: Enter user details into database
# 2: Read the data from the database
# 3: count of doses
# 4: Exit
#
# Enter your Choice -: 1
#
# Enter First Name -: jigar
# Enter Last Name -: deshmukh
# Enter Location -: kalyan
# Enter the Date-:23 june 2020
# Enter Age -: 23
# Enter Phone Number -:+919898776543
#
# Select Operation -:
#
# 1: Enter user details into database
# 2: Read the data from the database
# 3: count of doses
# 4: Exit
#
# Enter your Choice -: 1
#
# Enter First Name -: ketan
# Enter Last Name -: patil
# Enter Location -: kalyan
# Enter the Date-:23 june 2020
# Enter Age -: 23
# Enter Phone Number -:+918900765432
#
# Select Operation -:
#
# 1: Enter user details into database
# 2: Read the data from the database
# 3: count of doses
# 4: Exit
#
# Enter your Choice -: 3
# count of person in total-: 2
# Select Operation -:
#
# 1: Enter user details into database
# 2: Read the data from the database
# ...
